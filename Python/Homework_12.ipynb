# %%
import pandas as pd

# %% [markdown]
# ### Задание №1

# %%
df = pd.read_csv('/Users/kseniagorchakova/Library/Mobile Documents/com~apple~CloudDocs/Education/!Profession_DS/Python/Numpy_Pandas_Лекции и семинары/4_Лекция_доп.материалы/доп_материалы_к_пандас_1_и_2/visit_log.csv', sep = ';')

# %%
df.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
df.loc[df.traffic_source.isin(['google', 'yandex']), 'source_type'] = 'organic'
df.loc[df.traffic_source.isin(['paid', 'email']) & (df.region == 'Russia'), 'source_type'] = 'ad'
df.loc[df.traffic_source.isin(['paid', 'email']) & (df.region != 'Russia'), 'source_type'] = 'other'
df.loc[pd.isnull(df.source_type), 'source_type'] = df.traffic_source

# %%
df.head(30)
# Out:
#      timestamp    visit_id                                 url   region  \
# 0   1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1   1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2   1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3   1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4   1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# 5   1549980742  8855508aad  https://host.ru/df646c3676cc259fa0   Russia
# 6   1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15   Russia
# 7   1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e   Russia
# 8   1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867    China
# 9   1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0   Russia
# 10  1549980777  01d448afd9  https://host.ru/a5dda93e70318570c0    India
# 11  1549980785  71b6c1d538  https://host.ru/c8d9213a31839f9a3a  Ukraine
# ...

# %% [markdown]
# ### Задание №2

# %%
url = pd.read_csv('/Users/kseniagorchakova/Library/Mobile Documents/com~apple~CloudDocs/Education/!Profession_DS/Python/Numpy_Pandas_Лекции и семинары/4_Лекция_доп.материалы/доп_материалы_к_пандас_1_и_2/URLs.txt')

# %%
url.head()
# Out:
#                                                  url
# 0                                            /world/
# 1                                           /latest/
# 2                                      /?updated=top
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %%
import re

# %%
url[url.url.str.contains(pat = '\/\d{8}-', regex = True)]
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [84 rows x 1 columns]

# %% [markdown]
# ### Задание №3

# %%
ratings = pd.read_csv('/Users/kseniagorchakova/Library/Mobile Documents/com~apple~CloudDocs/Education/!Profession_DS/Python/Numpy_Pandas_Лекции и семинары/4_Лекция_доп.материалы/доп_материалы_к_пандас_1_и_2/ml-latest-small/ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
# Датафрейм, который сгруппирован по userId, и выведено только 2 столбца из первоначального датафрейма (userid и кол-во оценок каждого пользователя)
rating_count = ratings.groupby('userId').count().reset_index().filter(items = ['userId', 'movieId'])

# %%
# Max и min timestamp для каждого пользователя
max_timestamp = ratings.groupby('userId').max().reset_index().filter(items = ['userId', 'timestamp'])
min_timestamp = ratings.groupby('userId').min().reset_index().filter(items = ['userId', 'timestamp'])

# %%
# Соединение 3-х датафреймов (кол-во оценок у каждогого userId, Max и min timestamp для каждого пользователя)
joined = rating_count.merge(min_timestamp, on = 'userId', how = 'left').merge(max_timestamp, on = 'userId', how = 'left')

# %%
# Фильтр датафрейма по условие кол-во оценок > 100
joined_100 = all_joined[all_joined['movieId'] > 100]
joined_100.head()
# Out:
#     userId  movieId  timestamp_x  timestamp_y
# 3        4      204    949778714    949982274
# 7        8      116   1154389340   1154474527
# 14      15     1700    997937239   1469330735
# 16      17      363   1127468587   1127476640
# 18      19      423    855190091    855195373

# %%
# Функция, которая считает lifetime каждого пользователя
def average (row):
    return row['timestamp_y'] - row['timestamp_x']

# %%
joined_100['average'] = joined_100.apply(average, axis = 1)
# Out:
# <ipython-input-20-eb8470b403f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_100['average'] = joined_100.apply(average, axis = 1)

# %%
joined_100.head()
# Out:
#     userId  movieId  timestamp_x  timestamp_y      average
# 3        4      204    949778714    949982274     203560.0
# 7        8      116   1154389340   1154474527      85187.0
# 14      15     1700    997937239   1469330735  471393496.0
# 16      17      363   1127468587   1127476640       8053.0
# 18      19      423    855190091    855195373       5282.0

# %% [markdown]
# ### Задача №4
# Дана статистика услуг перевозок клиентов компании по типам:
# rzd - железнодорожные перевозки
# auto - автомобильные перевозки
# air - воздушные перевозки
# client_base - адреса клиентов

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %% [markdown]
# #### таблица с тремя типами выручки для каждого client_id без указания адреса клиента

# %%
client_revenue = rzd.merge(auto, on='client_id', how='outer').merge(air, on='client_id', how='outer')

# %%
client_revenue
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %% [markdown]
# #### аналогичную таблицу по типам выручки с указанием адреса клиента

# %%
client_revenue_address = client_base.merge(rzd, on='client_id', how='outer').merge(auto, on='client_id', how='outer').merge(air, on='client_id', how='outer')

# %%
client_revenue_address
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           NaN          NaN
# 1        112   Энтузиастов 8а       2810.0           NaN          NaN
# 2        113  Левобережная 1а      10283.0       57483.0          NaN
# 3        114          Мира 14       5774.0          83.0          NaN
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          NaN        4834.0          4.0
# 6        117  Панфиловская 33          NaN          98.0         13.0
# 7        118     Мастеркова 4          NaN           NaN        173.0
