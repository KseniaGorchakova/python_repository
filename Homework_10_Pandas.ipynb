# %%
import pandas as pd

# %% [markdown]
# ### Задача №1

# %%
data = pd.read_csv('/Users/kseniagorchakova/Library/Mobile Documents/com~apple~CloudDocs/Education/!Profession_DS/Python/Python_repository/data/ml-25m/ratings.csv')

# %%
data.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
# Фильтруем данные по признаку rating = 5
rating_5 = data[ (data['rating'] == 5.0) ]

# %%
# Считаем ко-во значений по столбку movieId
rating_5['movieId'].value_counts().head(1)
# Out:
# 318    39553
# Name: movieId, dtype: int64

# %% [markdown]
# ### Задача №2

# %%
power = pd.read_csv('/Users/kseniagorchakova/Library/Mobile Documents/com~apple~CloudDocs/Education/!Profession_DS/Python/Numpy_Pandas_Лекции и семинары/Лекция_2_Pandas_доп.материалы/power.csv')

# %%
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
# Фильтрация строк по странам и потреблению больше или равно 0
filtered_countries = power[ (power['country']=='Latvia') | (power['country']=='Lithuania') | (power['country']=='Estonia') & (power['quantity'] >= 0) ]

# %%
# Суммирование потребления в отфильтрованном датафрейме
filtered_countries['quantity'].sum()
# Out:
# 118002297.8915407

# %% [markdown]
# ### Задача №3

# %%
info = pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', encoding='utf-8')[1]

# %%
info
# Out:
#     Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
# 0          NaN            GBP/RUB      1007819      -              1002850
# 1          NaN            EUR/RUB       865925      -               861470
# 2          NaN            USD/RUB       727695      -               722358
# 3          NaN            JPY/RUB        06582      -                06530
# 4          NaN            CNY/RUB       112569      -               111888
# 5          NaN            CHF/RUB       790003      -               785428
# 6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
# 7          NaN            EUR/USD        11899      -                11926
# 8          NaN            EUR/GBP        08592      -                08594
# 9          NaN            EUR/JPY      1315400      -              1319100
# 10         NaN            EUR/CHF        10961      -                10971
# ...

# %%
type(info)
# Out:
# pandas.core.frame.DataFrame
